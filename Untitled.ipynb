# %%
import random
import json
import gym
from gym import spaces
import pandas as pd
import numpy as np

MAX_ACCOUNT_BALANCE = 100000
MAX_STEPS = 20000
INITIAL_ACCOUNT_BALANCE = 100


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(StockTradingEnv, self).__init__()

        self.df = df
        self.reward_range = (0, MAX_ACCOUNT_BALANCE)

        # Actions of the format Buy x%, Sell x%, Hold, etc.
        self.action_space = spaces.Box(low=np.array([-1]), high=np.array([1]), dtype=np.float16)

        # Prices contains the OHCL values for the last five prices
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(6, 6), dtype=np.float16)

    def _next_observation(self):
        # Get the stock data points for the last 5 days and scale to between 0-1
        frame = np.array([
            self.df.loc[self.current_step: self.current_step +
                        5, 'Open'].values,
            self.df.loc[self.current_step: self.current_step +
                        5, 'High'].values,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Low'].values,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Close'].values,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Volume'].values,
        ])
        
    
        # Append additional data and scale each value to between 0-1
        obs = np.append(frame, [[
            self.balance / MAX_ACCOUNT_BALANCE,
            self.share_balance / MAX_ACCOUNT_BALANCE,
            0,
            0,
            0,
            0
        ]], axis=0)

        return obs

    def _take_action(self, action):

        amount = action

        if action > 0:
            share_to_buy = min(self.balance, amount * self.share_balance)
            self.balance -= share_to_buy
            self.share_balance += share_to_buy

        elif action < 0:
    
            share_to_sell = amount * self.share_balance
            self.share_balance -= share_to_sell
            self.balance += share_to_sell
            
        price_p1 =  self.df.loc[self.current_step-1, "Close"]
        current_price =  self.df.loc[self.current_step, "Close"]
        price_increasing = (current_price - price_p1) / price_p1
        self.share_balance *= price_increasing

        self.net_worth_p1 = self.net_worth
        self.net_worth = self.balance + self.share_balance


    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1
        
        done = self.net_worth <= 0 
        
        if self.current_step > len(self.df.loc[:, 'Open'].values) - 6:
            self.current_step = 0
            done = 1

        reward = self.net_worth - self.net_worth_p1
        
        obs = self._next_observation()

        return obs, reward, done, {}

    def reset(self):
        # Reset the state of the environment to an initial state
        self.share_balance = 0
        self.balance = INITIAL_ACCOUNT_BALANCE
        self.net_worth = self.balance + self.share_balance
        
        self.current_step = random.randint(0, len(self.df.loc[:, 'Open'].values) - 100) 

        return self._next_observation()

    def render(self, mode='human', close=False):
        # Render the environment to the screen
        profit = self.net_worth - INITIAL_ACCOUNT_BALANCE

        print(f'Step: {self.current_step}')
        print(f'Balance: {self.balance}')
        print(f'{self.share_balance}')
        print(f'Net worth: {self.net_worth}')
        print(f'Profit: {profit}')

# %%
env = StockTradingEnv(df)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, deterministic=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, deterministic=True)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:86, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      84 episode_starts = np.ones((env.num_envs,), dtype=bool)
#      85 while (episode_counts < episode_count_targets).any():
# ---> 86     actions, states = model.predict(observations, state=states, episode_start=episode_starts, deterministic=deterministic)
#      87     observations, rewards, dones, infos = env.step(actions)
#      88     current_rewards += rewards
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/base_class.py:562, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     542 def predict(
#     543     self,
#     544     observation: np.ndarray,
#    (...)
#     547     deterministic: bool = False,
#     548 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     549     """
#     550     Get the policy action from an observation (and optional hidden state).
#     551     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     560         (used in recurrent policies)
#     561     """
# --> 562     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:338, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     335 observation, vectorized_env = self.obs_to_tensor(observation)
#     337 with th.no_grad():
# --> 338     actions = self._predict(observation, deterministic=deterministic)
#     339 # Convert to numpy
#     340 actions = actions.cpu().numpy()
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:630, in ActorCriticPolicy._predict(self, observation, deterministic)
#     622 def _predict(self, observation: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     623     """
#     624     Get the action according to the policy for a given observation.
#     625
#    (...)
#     628     :return: Taken action according to the policy
#     629     """
# --> 630     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:659, in ActorCriticPolicy.get_distribution(self, obs)
#     657 features = self.extract_features(obs)
#     658 latent_pi = self.mlp_extractor.forward_actor(features)
# --> 659 return self._get_action_dist_from_latent(latent_pi)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:607, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     604 mean_actions = self.action_net(latent_pi)
#     606 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 607     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     608 elif isinstance(self.action_dist, CategoricalDistribution):
#     609     # Here mean_actions are the logits before the softmax
#     610     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/distributions.py:152, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     144 """
#     145 Create the distribution given its parameters (mean, std)
#     146
#    (...)
#     149 :return:
#     150 """
#     151 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 152 self.distribution = Normal(mean_actions, action_std)
#     153 return self
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/torch/distributions/normal.py:50, in Normal.__init__(self, loc, scale, validate_args)
#      48 else:
#      49     batch_shape = self.loc.size()
# ---> 50 super(Normal, self).__init__(batch_shape, validate_args=validate_args)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/torch/distributions/distribution.py:55, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      53         valid = constraint.check(value)
#      54         if not valid.all():
# ---> 55             raise ValueError(
#      56                 f"Expected parameter {param} "
#      57                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      58                 f"of distribution {repr(self)} "
#      59                 f"to satisfy the constraint {repr(constraint)}, "
#      60                 f"but found invalid values:\n{value}"
#      61             )
#      62 super(Distribution, self).__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (1, 1)) of distribution Normal(loc: tensor([[nan]]), scale: tensor([[0.9943]])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan]])

# %%
import gym
import json
import datetime as dt
import pandas as pd

df = pd.read_csv('./BTCUSD_2017_heure.csv')
#df["Local time"] = pd.to_datetime(df["Local time"], utc=True)
#df = df.sort_values('Local time')

#from stable_baselines3.common.policies import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO

# The algorithms require a vectorized environment to run
env = DummyVecEnv([lambda: StockTradingEnv(df)])

model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)


model.learn(total_timesteps=5000)

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
#model = PPO2(MlpPolicy, env, verbose=1)
#model.learn(total_timesteps=20000)

#obs = env.reset()
#for i in range(2000):
#    action, _states = model.predict(obs)
#    obs, rewards, done, info = env.step(action)
#    env.render()
# Out:
# /home/gregory.guichard@cdbdx.biz/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# <__array_function__ internals>:180: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 608  |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 1024 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0057535004 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -4.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0308      |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00232     |
# |    std                  | 1            |
# |    value_loss           | 0.0038       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0028798846 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00584     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0268      |
# |    n_updates            | 8            |
# |    policy_gradient_loss | 0.000248     |
# |    std                  | 0.998        |
# |    value_loss           | 0.000127     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0039683264 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.934       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0141      |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 0.99         |
# |    value_loss           | 0.000198     |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 535            |
# |    iterations           | 5              |
# |    time_elapsed         | 9              |
# |    total_timesteps      | 5120           |
# | train/                  |                |
# |    approx_kl            | 1.27718085e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.41          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | -0.0136        |
# |    n_updates            | 16             |
# |    policy_gradient_loss | 0.000343       |
# |    std                  | 0.99           |
# |    value_loss           | 0.000127       |
# --------------------------------------------
# /home/gregory.guichard@cdbdx.biz/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [49], in <cell line: 32>()
#      18 model = PPO(
#      19     policy = 'MlpPolicy',
#      20     env = env,
#    (...)
#      26     ent_coef = 0.01,
#      27     verbose=1)
#      30 model.learn(total_timesteps=5000)
# ---> 32 mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, deterministic=True)
#      33 print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:86, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      84 episode_starts = np.ones((env.num_envs,), dtype=bool)
#      85 while (episode_counts < episode_count_targets).any():
# ---> 86     actions, states = model.predict(observations, state=states, episode_start=episode_starts, deterministic=deterministic)
#      87     observations, rewards, dones, infos = env.step(actions)
#      88     current_rewards += rewards
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/base_class.py:562, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     542 def predict(
#     543     self,
#     544     observation: np.ndarray,
#    (...)
#     547     deterministic: bool = False,
#     548 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     549     """
#     550     Get the policy action from an observation (and optional hidden state).
#     551     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     560         (used in recurrent policies)
#     561     """
# --> 562     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:338, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     335 observation, vectorized_env = self.obs_to_tensor(observation)
#     337 with th.no_grad():
# --> 338     actions = self._predict(observation, deterministic=deterministic)
#     339 # Convert to numpy
#     340 actions = actions.cpu().numpy()
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:630, in ActorCriticPolicy._predict(self, observation, deterministic)
#     622 def _predict(self, observation: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     623     """
#     624     Get the action according to the policy for a given observation.
#     625
#    (...)
#     628     :return: Taken action according to the policy
#     629     """
# --> 630     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:659, in ActorCriticPolicy.get_distribution(self, obs)
#     657 features = self.extract_features(obs)
#     658 latent_pi = self.mlp_extractor.forward_actor(features)
# --> 659 return self._get_action_dist_from_latent(latent_pi)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/policies.py:607, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     604 mean_actions = self.action_net(latent_pi)
#     606 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 607     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     608 elif isinstance(self.action_dist, CategoricalDistribution):
#     609     # Here mean_actions are the logits before the softmax
#     610     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/stable_baselines3/common/distributions.py:152, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     144 """
#     145 Create the distribution given its parameters (mean, std)
#     146
#    (...)
#     149 :return:
#     150 """
#     151 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 152 self.distribution = Normal(mean_actions, action_std)
#     153 return self
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/torch/distributions/normal.py:50, in Normal.__init__(self, loc, scale, validate_args)
#      48 else:
#      49     batch_shape = self.loc.size()
# ---> 50 super(Normal, self).__init__(batch_shape, validate_args=validate_args)
#
# File ~/.cache/pypoetry/virtualenvs/btc-rl-vMrsoe6R-py3.8/lib/python3.8/site-packages/torch/distributions/distribution.py:55, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      53         valid = constraint.check(value)
#      54         if not valid.all():
# ---> 55             raise ValueError(
#      56                 f"Expected parameter {param} "
#      57                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      58                 f"of distribution {repr(self)} "
#      59                 f"to satisfy the constraint {repr(constraint)}, "
#      60                 f"but found invalid values:\n{value}"
#      61             )
#      62 super(Distribution, self).__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (1, 1)) of distribution Normal(loc: tensor([[nan]]), scale: tensor([[0.9943]])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan]])

# %%
import random
import json
import gym
from gym import spaces
import pandas as pd
import numpy as np

MAX_ACCOUNT_BALANCE = 2147483647
MAX_NUM_SHARES = 2147483647
MAX_SHARE_PRICE = 5000
MAX_OPEN_POSITIONS = 5
MAX_STEPS = 20000

INITIAL_ACCOUNT_BALANCE = 10000


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(StockTradingEnv, self).__init__()

        self.df = df
        self.reward_range = (0, MAX_ACCOUNT_BALANCE)

        # Actions of the format Buy x%, Sell x%, Hold, etc.
        self.action_space = spaces.Box(
            low=np.array([-1]), high=np.array([1]), dtype=np.float16)

        # Prices contains the OHCL values for the last five prices
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(6, 6), dtype=np.float16)

    def _next_observation(self):
        # Get the stock data points for the last 5 days and scale to between 0-1
        frame = np.array([
            self.df.loc[self.current_step: self.current_step +
                        5, 'Open'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'High'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Low'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Close'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Volume'].values / MAX_NUM_SHARES,
        ])

        # Append additional data and scale each value to between 0-1
        obs = np.append(frame, [[
            self.balance / MAX_ACCOUNT_BALANCE,
            self.max_net_worth / MAX_ACCOUNT_BALANCE,
            self.shares_held / MAX_NUM_SHARES,
            self.cost_basis / MAX_SHARE_PRICE,
            self.total_shares_sold / MAX_NUM_SHARES,
            self.total_sales_value / (MAX_NUM_SHARES * MAX_SHARE_PRICE),
        ]], axis=0)

        return obs

    def _take_action(self, action):
        # Set the current price to a random price within the time step
        current_price = random.uniform(
            self.df.loc[self.current_step, "Open"], self.df.loc[self.current_step, "Close"])
        
        
        action = action[0]

        if action > 0:
            # Buy amount % of balance in shares
            amount_to_buy = action
            if amount_to_buy > self.balance:
                amount_to_buy = self.balance
                
            self.balance += amount_to_buy
            
            
            total_possible = int(self.balance / current_price)
            shares_bought = int(total_possible * amount)
            prev_cost = self.cost_basis * self.shares_held
            additional_cost = shares_bought * current_price

            self.balance -= additional_cost
            self.cost_basis = (
                prev_cost + additional_cost) / (self.shares_held + shares_bought)
            self.shares_held += shares_bought

        elif action < 0:
            # Sell amount % of shares held
            shares_sold = int(self.shares_held * amount)
            self.balance += shares_sold * current_price
            self.shares_held -= shares_sold
            self.total_shares_sold += shares_sold
            self.total_sales_value += shares_sold * current_price

        self.net_worth = self.balance + self.shares_held * current_price

        if self.net_worth > self.max_net_worth:
            self.max_net_worth = self.net_worth

        if self.shares_held == 0:
            self.cost_basis = 0

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        if self.current_step > len(self.df.loc[:, 'Open'].values) - 6:
            self.current_step = 0

        delay_modifier = (self.current_step / MAX_STEPS)

        reward = self.balance * delay_modifier
        done = self.net_worth <= 0

        obs = self._next_observation()

        return obs, reward, done, {}

    def reset(self):
        # Reset the state of the environment to an initial state
        self.balance = INITIAL_ACCOUNT_BALANCE
        self.net_worth = INITIAL_ACCOUNT_BALANCE
        self.max_net_worth = INITIAL_ACCOUNT_BALANCE
        self.shares_held = 0
        self.cost_basis = 0
        self.total_shares_sold = 0
        self.total_sales_value = 0

        # Set the current step to a random point within the data frame
        self.current_step = random.randint(
            0, len(self.df.loc[:, 'Open'].values) - 6)

        return self._next_observation()

    def render(self, mode='human', close=False):
        # Render the environment to the screen
        profit = self.net_worth - INITIAL_ACCOUNT_BALANCE

        print(f'Step: {self.current_step}')
        print(f'Balance: {self.balance}')
        print(
            f'Shares held: {self.shares_held} (Total sold: {self.total_shares_sold})')
        print(
            f'Avg cost for held shares: {self.cost_basis} (Total sales value: {self.total_sales_value})')
        print(
            f'Net worth: {self.net_worth} (Max net worth: {self.max_net_worth})')
        print(f'Profit: {profit}')
